# %%
#Realizaremos los graficos correspondientes que nos brindan info de los diamantes robados

#Importamos Librerias
import pandas as pd
import cufflinks as cf
from IPython.display import display,HTML
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
#Importamos base de datos estandarizada
df_board = pd.read_csv('datafinal.csv')

# %%
#Revisamos encabezados
df_board.head()
# Out:
#    Unnamed: 0  Carat      Cut Color Clarity  Depth  Table  Price
# 0           0   0.23    Ideal     E     SI2   61.5   55.0    326
# 1           1   0.21  Premium     E     SI1   59.8   61.0    326
# 2           2   0.23     Good     E     VS1   56.9   65.0    327
# 3           3   0.29  Premium     I     VS2   62.4   58.0    334
# 4           4   0.31     Good     J     SI2   63.3   58.0    335

# %%
#Por el momento eliminaremos dos  columnas, ya que nos concentraremos en obtener otros graficos para identificar insights.
df_board = df_board.drop(columns = ["Unnamed: 0","Table"])
df_board
# Out:
#        Carat       Cut Color Clarity  Depth  Price
# 0       0.23     Ideal     E     SI2   61.5    326
# 1       0.21   Premium     E     SI1   59.8    326
# 2       0.23      Good     E     VS1   56.9    327
# 3       0.29   Premium     I     VS2   62.4    334
# 4       0.31      Good     J     SI2   63.3    335
# ...      ...       ...   ...     ...    ...    ...
# 53925   0.72     Ideal     D     SI1   60.8   2757
# 53926   0.72      Good     D     SI1   63.1   2757
# 53927   0.70  VeryGood     D     SI1   62.8   2757
# 53928   0.86   Premium     H     SI2   61.0   2757
# 53929   0.75     Ideal     D     SI2   61.0   2757
#
# [53930 rows x 6 columns]

# %%
#Revisamos encabezados de columnas
df_board.columns
# Out:
# Index(['Carat', 'Cut', 'Color', 'Clarity', 'Depth', 'Price'], dtype='object')

# %%
#Exportamos data lista para usarlo en el Dashboard
df_board.to_csv('datagrap.csv', index=False)

# %%
#Gráfico 1: Obtenemos la relación entre la característica Depth y el Precio de los diamantes
plt.scatter(df_board["Price"], df_board["Depth"])
plt.xlabel("Price", color = 'green')
plt.ylabel("Depth", color = 'green')
plt.show()

# %%
#Gráfico 1: Obtenemos la relación entre el Precio y los quilates de los diamantes
plt.scatter(df_board["Carat"], df_board["Price"])
plt.xlabel("Carat", color = 'green')
plt.ylabel("Price", color ='green')
plt.show()

# %%
#Obtenemos la suma de la cantidad de diamantes por corte que se robaron
serie_cut = df_board.Cut.value_counts()

#Graficamos este conteo
serie_cut = serie_cut.sort_values(ascending=True)
serie_cut.plot.barh()
# Out:
# <Axes: ylabel='Cut'>
